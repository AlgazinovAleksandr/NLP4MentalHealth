# %%
import pandas as pd

# %%
df = pd.read_csv("questionnaire_sample_1.csv")
df
# Out:
#    persona_id                                persona_description  \
# 0    test_001  22-year-old female student, mentally healthy, ...
# 1    test_002  46-year-old employed male who follows wellness...
# 2    test_003  58-year-old retired woman, generally content, ...
# 3    test_004  15-year-old student who prefers not to disclos...
# 4    test_005  29-year-old unemployed woman with persistent l...
# 5    test_006  42-year-old employed man experiencing gradual ...
# 6    test_007  24-year-old female student with severe general...
# 7    test_008  36-year-old employed man dealing with persiste...
# 8    test_009  17-year-old male student struggling with susta...
# 9    test_010  31-year-old employed woman who has struggled w...
# 10   test_011  26-year-old employed male who has always found...
# 11   test_012  34-year-old employed woman with trauma history...
# 12   test_013  20-year-old female student experiencing severe...
# ...
